# %% [markdown]
# # German Power Company
# ## Jacklyn Tellez
# ## Indiviual Project 3
# ### Version 1.0
# ### Spring 2022

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The following code is the code I used to insert the data and check that it is inserted.

# %%
hdf = pd.read_csv(r'C:\Users\jackl\Desktop\DS160\IP3\50Hertz.csv')

# %%
hdf
# Out:
#            Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0    23/08/2019        74        73        63        55        54        53
# 1    24/08/2019        37        38        35        35        31        32
# 2    25/08/2019        93        88        85        81        76        80
# 3    26/08/2019        72        66        59        54        48        46
# 4    27/08/2019        39        38        36        36        34        31
# ..          ...       ...       ...       ...       ...       ...       ...
# 392  18/09/2020        73        72        66        62        59        58
# 393  19/09/2020        64        64        64        68        66        66
# 394  20/09/2020       111       102        95        87        82        83
# 395  21/09/2020        57        53        47        44        43        42
# 396  22/09/2020        51        48        44        42        40        39
#
# ...

# %%
adf = pd.read_csv(r'C:\Users\jackl\Desktop\DS160\IP3\Amprion.csv')

# %%
adf
# Out:
#            Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0    23/08/2019         5         5         6         7         6         5
# 1    24/08/2019        62        60        55        55        54        52
# 2    25/08/2019        29        29        29        30        28        27
# 3    26/08/2019        13        12        12        11        12        12
# 4    27/08/2019        21        20        19        16        15        14
# ..          ...       ...       ...       ...       ...       ...       ...
# 392  18/09/2020       116       117       117       113       114       114
# 393  19/09/2020        91        92        91        92        92        90
# 394  20/09/2020        60        59        58        55        52        50
# 395  21/09/2020        44        44        40        39        37        36
# 396  22/09/2020        11        11        10        10        10        10
#
# ...

# %%
ttdf = pd.read_csv(r'C:\Users\jackl\Desktop\DS160\IP3\TenneTTSO.csv')

# %%
ttdf
# Out:
#            Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0    23/08/2019      9.68     10.16     10.94     11.39     12.09     12.79
# 1    24/08/2019     67.94     67.52     64.48     64.78     65.75     65.07
# 2    25/08/2019     89.38     88.95     85.13     82.74     81.46     77.92
# 3    26/08/2019     33.71     31.84     32.75     33.33     32.02     30.97
# 4    27/08/2019     52.65     47.95     44.61     43.80     41.00     41.23
# ..          ...       ...       ...       ...       ...       ...       ...
# 392  18/09/2020    124.69    121.15    116.35    117.81    113.87    112.95
# 393  19/09/2020    136.90    134.27    127.98    121.21    116.74    112.38
# 394  20/09/2020     82.05     79.81     80.18     80.94     79.70     77.91
# 395  21/09/2020     55.75     53.17     51.77     50.08     48.95     47.45
# 396  22/09/2020     11.66     11.72     11.08      9.94     10.08      9.36
#
# ...

# %%
tbdf = pd.read_csv(r'C:\Users\jackl\Desktop\DS160\IP3\TransnetBW.csv')

# %%
tbdf
# Out:
#            Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0    23/08/2019      1.44      1.38      1.38      1.50      1.77      1.87
# 1    24/08/2019     22.43     22.25     22.03     23.34     24.81     22.90
# 2    25/08/2019      0.75      1.06      0.72      1.00      0.80      0.95
# 3    26/08/2019      0.56      0.85      0.56      0.40      0.46      0.39
# 4    27/08/2019      1.08      1.02      0.98      0.84      0.57      0.46
# ..          ...       ...       ...       ...       ...       ...       ...
# 392  18/09/2020     43.00     44.43     44.33     46.67     46.67     46.67
# 393  19/09/2020     37.43     35.22     36.60     33.44     32.67     36.00
# 394  20/09/2020      5.00      5.00      5.00      5.00      4.22      4.22
# 395  21/09/2020      3.44      3.44      3.44      3.44      2.67      3.44
# 396  22/09/2020      1.33      2.00      2.00      2.00      1.00      1.00
#
# ...

# %% [markdown]
# Converting the date.

# %%
hdf['Date'] = pd.to_datetime(hdf['Date'], dayfirst=True)

# %%
hdf.head(2)
# Out:
#         Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0 2019-08-23        74        73        63        55        54        53
# 1 2019-08-24        37        38        35        35        31        32
#
#    01:30:00  01:45:00  02:00:00  ...  21:30:00  21:45:00  22:00:00  22:15:00  \
# 0        51        52        45  ...        68        68        63        61
# 1        30        29        28  ...       118       118       112       107
#
#    22:30:00  22:45:00  23:00:00  23:15:00  23:30:00  23:45:00
# 0        57        52        51        49        45        40
# 1       104       104        99        95        95        96
#
# [2 rows x 97 columns]

# %%
adf['Date'] = pd.to_datetime(adf['Date'], dayfirst=True)

# %%
adf.head(2)
# Out:
#         Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0 2019-08-23         5         5         6         7         6         5
# 1 2019-08-24        62        60        55        55        54        52
#
#    01:30:00  01:45:00  02:00:00  ...  21:30:00  21:45:00  22:00:00  22:15:00  \
# 0         5         5         5  ...        72        69        66        67
# 1        51        50        49  ...        34        33        31        31
#
#    22:30:00  22:45:00  23:00:00  23:15:00  23:30:00  23:45:00
# 0        66        69        68        65        61        64
# 1        31        31        31        31        27        28
#
# [2 rows x 97 columns]

# %%
ttdf['Date'] = pd.to_datetime(ttdf['Date'], dayfirst=True)

# %%
ttdf.head(2)
# Out:
#         Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0 2019-08-23      9.68     10.16     10.94     11.39     12.09     12.79
# 1 2019-08-24     67.94     67.52     64.48     64.78     65.75     65.07
#
#    01:30:00  01:45:00  02:00:00  ...  21:30:00  21:45:00  22:00:00  22:15:00  \
# 0     13.33     13.88     14.73  ...     73.52     74.03     74.77     73.32
# 1     63.39     63.69     64.37  ...    116.79    114.30    110.81    109.76
#
#    22:30:00  22:45:00  23:00:00  23:15:00  23:30:00  23:45:00
# 0     74.83     73.10     71.26     71.95     69.97     69.58
# 1    106.55    102.31     99.04     96.57     94.75     91.73
#
# [2 rows x 97 columns]

# %%
tbdf['Date'] = pd.to_datetime(tbdf['Date'], dayfirst=True)

# %%
tbdf.head(2)
# Out:
#         Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0 2019-08-23      1.44      1.38      1.38      1.50      1.77      1.87
# 1 2019-08-24     22.43     22.25     22.03     23.34     24.81     22.90
#
#    01:30:00  01:45:00  02:00:00  ...  21:30:00  21:45:00  22:00:00  22:15:00  \
# 0      1.95      2.47      2.68  ...     21.99     18.33     18.56     18.56
# 1     22.77     19.49     22.58  ...      1.67      1.35      1.34      0.97
#
#    22:30:00  22:45:00  23:00:00  23:15:00  23:30:00  23:45:00
# 0     17.11     14.19     15.69     16.71     18.88     21.67
# 1      1.41      1.50      1.30      1.23      1.15      1.01
#
# [2 rows x 97 columns]

# %% [markdown]
# Adding a column with the company name for each dataframe.

# %%
hdf.insert(0, "Company", ['50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', 
                          '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz', '50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', 
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz',
                          '50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz', '50Hertz'] , True)

# %%
hdf.head(2)
# Out:
#    Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0  50Hertz 2019-08-23        74        73        63        55        54
# 1  50Hertz 2019-08-24        37        38        35        35        31
#
#    01:15:00  01:30:00  01:45:00  ...  21:30:00  21:45:00  22:00:00  22:15:00  \
# 0        53        51        52  ...        68        68        63        61
# 1        32        30        29  ...       118       118       112       107
#
#    22:30:00  22:45:00  23:00:00  23:15:00  23:30:00  23:45:00
# 0        57        52        51        49        45        40
# 1       104       104        99        95        95        96
#
# [2 rows x 98 columns]

# %%
adf.insert(0, "Company", ['Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion',
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion',
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion',
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion',
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion',
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion',
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion',
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion',
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion',  
                          'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion', 'Amprion'], True)

# %%
adf.head(2)
# Out:
#    Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0  Amprion 2019-08-23         5         5         6         7         6
# 1  Amprion 2019-08-24        62        60        55        55        54
#
#    01:15:00  01:30:00  01:45:00  ...  21:30:00  21:45:00  22:00:00  22:15:00  \
# 0         5         5         5  ...        72        69        66        67
# 1        52        51        50  ...        34        33        31        31
#
#    22:30:00  22:45:00  23:00:00  23:15:00  23:30:00  23:45:00
# 0        66        69        68        65        61        64
# 1        31        31        31        31        27        28
#
# [2 rows x 98 columns]

# %%
ttdf.insert(0, "Company", ['TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO',
                           'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO', 'TenneTTSO'], True)

# %%
ttdf.head(2)
# Out:
#      Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0  TenneTTSO 2019-08-23      9.68     10.16     10.94     11.39     12.09
# 1  TenneTTSO 2019-08-24     67.94     67.52     64.48     64.78     65.75
#
#    01:15:00  01:30:00  01:45:00  ...  21:30:00  21:45:00  22:00:00  22:15:00  \
# 0     12.79     13.33     13.88  ...     73.52     74.03     74.77     73.32
# 1     65.07     63.39     63.69  ...    116.79    114.30    110.81    109.76
#
#    22:30:00  22:45:00  23:00:00  23:15:00  23:30:00  23:45:00
# 0     74.83     73.10     71.26     71.95     69.97     69.58
# 1    106.55    102.31     99.04     96.57     94.75     91.73
#
# [2 rows x 98 columns]

# %%
tbdf.insert(0, "Company", ['TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW',
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW',
                           'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', 'TransnetBW', ])

# %%
tbdf.head(2)
# Out:
#       Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0  TransnetBW 2019-08-23      1.44      1.38      1.38      1.50      1.77
# 1  TransnetBW 2019-08-24     22.43     22.25     22.03     23.34     24.81
#
#    01:15:00  01:30:00  01:45:00  ...  21:30:00  21:45:00  22:00:00  22:15:00  \
# 0      1.87      1.95      2.47  ...     21.99     18.33     18.56     18.56
# 1     22.90     22.77     19.49  ...      1.67      1.35      1.34      0.97
#
#    22:30:00  22:45:00  23:00:00  23:15:00  23:30:00  23:45:00
# 0     17.11     14.19     15.69     16.71     18.88     21.67
# 1      1.41      1.50      1.30      1.23      1.15      1.01
#
# [2 rows x 98 columns]

# %% [markdown]
# Combining the four dataframes

# %%
df1 = pd.concat([hdf, adf, ttdf, tbdf])

# %%
df1
# Out:
#         Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0       50Hertz 2019-08-23     74.00     73.00     63.00     55.00     54.00
# 1       50Hertz 2019-08-24     37.00     38.00     35.00     35.00     31.00
# 2       50Hertz 2019-08-25     93.00     88.00     85.00     81.00     76.00
# 3       50Hertz 2019-08-26     72.00     66.00     59.00     54.00     48.00
# 4       50Hertz 2019-08-27     39.00     38.00     36.00     36.00     34.00
# ..          ...        ...       ...       ...       ...       ...       ...
# 392  TransnetBW 2020-09-18     43.00     44.43     44.33     46.67     46.67
# 393  TransnetBW 2020-09-19     37.43     35.22     36.60     33.44     32.67
# 394  TransnetBW 2020-09-20      5.00      5.00      5.00      5.00      4.22
# 395  TransnetBW 2020-09-21      3.44      3.44      3.44      3.44      2.67
# 396  TransnetBW 2020-09-22      1.33      2.00      2.00      2.00      1.00
#
# ...

# %% [markdown]
# Finding the names of the columns so i can find the means of the colunms by year and company.

# %%
hdf.columns
# Out:
# Index(['Company', 'Date', '00:00:00', '00:15:00', '00:30:00', '00:45:00',
#        '01:00:00', '01:15:00', '01:30:00', '01:45:00', '02:00:00', '02:15:00',
#        '02:30:00', '02:45:00', '03:00:00', '03:15:00', '03:30:00', '03:45:00',
#        '04:00:00', '04:15:00', '04:30:00', '04:45:00', '05:00:00', '05:15:00',
#        '05:30:00', '05:45:00', '06:00:00', '06:15:00', '06:30:00', '06:45:00',
#        '07:00:00', '07:15:00', '07:30:00', '07:45:00', '08:00:00', '08:15:00',
#        '08:30:00', '08:45:00', '09:00:00', '09:15:00', '09:30:00', '09:45:00',
#        '10:00:00', '10:15:00', '10:30:00', '10:45:00', '11:00:00', '11:15:00',
#        '11:30:00', '11:45:00', '12:00:00', '12:15:00', '12:30:00', '12:45:00',
#        '13:00:00', '13:15:00', '13:30:00', '13:45:00', '14:00:00', '14:15:00',
#        '14:30:00', '14:45:00', '15:00:00', '15:15:00', '15:30:00', '15:45:00',
#        '16:00:00', '16:15:00', '16:30:00', '16:45:00', '17:00:00', '17:15:00',
# ...

# %% [markdown]
# Finding the mean by Company and date

# %%
df2 = df1.groupby([df1['Company'], df1['Date'].dt.year]).mean()

# %%
df2
# Out:
#                    00:00:00    00:15:00    00:30:00    00:45:00    01:00:00  \
# Company    Date
# 50Hertz    2019  143.320611  142.351145  142.366412  142.000000  141.900763
#            2020  141.894737  141.124060  140.936090  140.838346  140.281955
# Amprion    2019  106.992366  106.679389  106.091603  105.549618  108.083969
#            2020   93.751880   94.312030   94.424812   94.033835   93.657895
# TenneTTSO  2019  150.866183  150.450992  150.152901  149.611679  148.946412
#            2020  141.603835  141.457105  141.203120  141.206278  140.931617
# TransnetBW 2019   39.293740   39.462290   39.165191   39.138321   39.369084
#            2020   30.899023   30.604737   30.354023   29.871128   29.731955
#
#                    01:15:00    01:30:00    01:45:00    02:00:00    02:15:00  \
# Company    Date
# 50Hertz    2019  141.381679  140.648855  140.923664  140.732824  140.458015
#            2020  140.037594  139.462406  139.112782  138.646617  138.560150
# ...

# %% [markdown]
# extracting a dataframe for noon and midnight

# %%
midnight = df2[['00:00:00']].copy()

# %%
midnight
# Out:
#                    00:00:00
# Company    Date
# 50Hertz    2019  143.320611
#            2020  141.894737
# Amprion    2019  106.992366
#            2020   93.751880
# TenneTTSO  2019  150.866183
#            2020  141.603835
# TransnetBW 2019   39.293740
#            2020   30.899023

# %%
noon = df2[['12:00:00']].copy()

# %%
noon
# Out:
#                    12:00:00
# Company    Date
# 50Hertz    2019  142.473282
#            2020  163.398496
# Amprion    2019  100.572519
#            2020  101.357143
# TenneTTSO  2019  149.229466
#            2020  162.944436
# TransnetBW 2019   37.772366
#            2020   25.731053

# %% [markdown]
# Puting the midnight and noon means into horizontal bar chart

# %%
midnight_chart = midnight.plot.barh( y='00:00:00', title='TW/hours by Company/Date @ Midnight', color='red')

# %%
noon_chart = noon.plot.barh( y='12:00:00', title='TW/hours by Company/Date @ Noon', color='blue')

# %%
midnight_chart.figure.savefig('midnight.png')

# %%
noon_chart.figure.savefig('noon.png')

# %%
frames = [midnight, noon]

# %%
combine = pd.concat(frames)

# %%
combine
# Out:
#                    00:00:00    12:00:00
# Company    Date
# 50Hertz    2019  143.320611         NaN
#            2020  141.894737         NaN
# Amprion    2019  106.992366         NaN
#            2020   93.751880         NaN
# TenneTTSO  2019  150.866183         NaN
#            2020  141.603835         NaN
# TransnetBW 2019   39.293740         NaN
#            2020   30.899023         NaN
# 50Hertz    2019         NaN  142.473282
#            2020         NaN  163.398496
# Amprion    2019         NaN  100.572519
#            2020         NaN  101.357143
# TenneTTSO  2019         NaN  149.229466
#            2020         NaN  162.944436
# TransnetBW 2019         NaN   37.772366
#            2020         NaN   25.731053

# %%
Creating a subplot of the noon and midnight bar charts.

# %%
axes = combine.plot.barh(rot=0, subplots=True)
axes = combine.plot.barh(color={"00:00:00": "silver", "12:00:00": "gray"})

# %%
axes.figure.savefig('combine_bar_chart.png')

# %% [markdown]
# creating dataframes for a specific day then making an area graph.

# %%
daily_values_h = pd.DataFrame({'2019/08/24':[37, 38, 35, 35, 31, 32, 30,29,
                                             28,28,27,27,28,30,30,32,33,33,33,
                                             33,34,33,35,32,29,22,17,13,9,8,8,
                                             9,12,16,21,27,34,40,47,54,57,59,56,
                                             61,61,60,63,59,59,63,61,68,66,69,75,
                                             74,73,74,76,79,79,80,80,82,83,77,81,
                                             78,80,79,77,75,74,79,87,90,98,109,114,
                                             117,121,122,125,125,123,119,118,118,112,
                                             107,104,104,99,95,95,96]}, 
                              index=['00:00:00', '0:15:00','0:30:00','0:45:00','1:00:00','1:15:00','1:30:00',
                                     '1:45:00','2:00:00','2:15:00','2:30:00','2:45:00','3:00:00','3:15:00',
                                     '3:30:00','3:45:00','4:00:00','4:15:00','4:30:00','4:45:00','5:00:00',
                                     '5:15:00','5:30:00','5:45:00','6:00:00','6:15:00','6:30:00','6:45:00',
                                     '7:00:00','7:15:00','7:30:00','7:45:00','8:00:00','8:15:00','8:30:00',
                                     '8:45:00','9:00:00','9:15:00','9:30:00','9:45:00','10:00:00','10:15:00',
                                     '10:30:00','10:45:00','11:00:00','11:15:00','11:30:00','11:45:00','12:00:00',
                                     '12:15:00','12:30:00','12:45:00','13:00:00','13:15:00','13:30:00','13:45:00',
                                     '14:00:00','14:15:00','14:30:00','14:45:00','15:00:00','15:15:00','15:30:00',
                                     '15:45:00','16:00:00','16:15:00','16:30:00','16:45:00','17:00:00','17:15:00',
                                     '17:30:00','17:45:00','18:00:00','18:15:00','18:30:00','18:45:00','19:00:00',
                                     '19:15:00','19:30:00','19:45:00','20:00:00','20:15:00','20:30:00','20:45:00',
                                     '21:00:00','21:15:00','21:30:00','21:45:00','22:00:00','22:15:00','22:30:00',
                                     '22:45:00','23:00:00','23:15:00','23:30:00','23:45:00'])

# %%
daily_values_h
# Out:
#           2019/08/24
# 00:00:00          37
# 0:15:00           38
# 0:30:00           35
# 0:45:00           35
# 1:00:00           31
# ...              ...
# 22:45:00         104
# 23:00:00          99
# 23:15:00          95
# 23:30:00          95
# 23:45:00          96
#
# [96 rows x 1 columns]

# %%
daily_view= daily_values_h.plot.area(title='Power Production: 50Hertz/2019-08-24')
daily_view.set_ylabel('TW/h Generated')
daily_view.set_xlabel('Time of Day')
# Out:
# Text(0.5, 0, 'Time of Day')

# %%
daily_values_a = pd.DataFrame({'Amprion/2019-08-24':[62,60,55,55,54,52,51,50,49,45,44,45,45,43,45,46,45,47,50,50,51,51,
                                             53,51,47,43,39,31,23,17,15,13,12,13,13,15,20,22,23,24,23,24,24,25,
                                             24,26,26,24,25,23,24,24,23,25,24,25,25,26,27,28,27,25,28,26,27,25,
                                             24,22,22,21,21,22,26,30,31,34,34,37,40,40,40,40,38,36,35,34,34,33,
                                             31,31,31,31,31,31,27,28]},
                             index=['00:00:00', '0:15:00','0:30:00','0:45:00','1:00:00','1:15:00','1:30:00',
                                     '1:45:00','2:00:00','2:15:00','2:30:00','2:45:00','3:00:00','3:15:00',
                                     '3:30:00','3:45:00','4:00:00','4:15:00','4:30:00','4:45:00','5:00:00',
                                     '5:15:00','5:30:00','5:45:00','6:00:00','6:15:00','6:30:00','6:45:00',
                                     '7:00:00','7:15:00','7:30:00','7:45:00','8:00:00','8:15:00','8:30:00',
                                     '8:45:00','9:00:00','9:15:00','9:30:00','9:45:00','10:00:00','10:15:00',
                                     '10:30:00','10:45:00','11:00:00','11:15:00','11:30:00','11:45:00','12:00:00',
                                     '12:15:00','12:30:00','12:45:00','13:00:00','13:15:00','13:30:00','13:45:00',
                                     '14:00:00','14:15:00','14:30:00','14:45:00','15:00:00','15:15:00','15:30:00',
                                     '15:45:00','16:00:00','16:15:00','16:30:00','16:45:00','17:00:00','17:15:00',
                                     '17:30:00','17:45:00','18:00:00','18:15:00','18:30:00','18:45:00','19:00:00',
                                     '19:15:00','19:30:00','19:45:00','20:00:00','20:15:00','20:30:00','20:45:00',
                                     '21:00:00','21:15:00','21:30:00','21:45:00','22:00:00','22:15:00','22:30:00',
                                     '22:45:00','23:00:00','23:15:00','23:30:00','23:45:00'])

# %%
daily_view= daily_values_a.plot.area(title='Power Production: Amprion/2019-08-24')
daily_view.set_ylabel('TW/h Generated')
daily_view.set_xlabel('Time of Day')
# Out:
# Text(0.5, 0, 'Time of Day')

# %%
daily_values_tt = pd.DataFrame({'TenneTTSO/2019-08-24':[67.94,67.52,64.48,64.78,65.75,65.07,63.39,63.69,64.37,65.39,65.53,
                                               66.95,67.96,69.39,70.63,70.64,70.01,72.63,75.39,76.92,76.24,74.74,
                                               71.04,63.7,54.93,47.31,41,34.24,28.82,24.16,21.85,21.47,22.1,23.7,
                                               26.89,30.94,36.91,42.59,46.84,49.03,52.12,52.22,52.88,51.23,54.44,
                                               56.72,57.56,58.78,60.4,61.18,63.55,61.43,63.98,64.62,65.6,65.66,
                                               64.07,66.03,66.5,67.12,66.35,64.64,66.25,66.95,67.72,65.64,64.02,
                                               61.44,58.3,52.78,52.34,52.56,56.76,63.56,72.21,81.34,92.91,98.31,
                                               105,112.49,112.78,116.68,115.85,116.95,119.86,118.01,116.79,114.3,
                                               110.81,109.76,106.55,102.31,99.04,96.57,94.75,91.73]},
                              index=['00:00:00', '0:15:00','0:30:00','0:45:00','1:00:00','1:15:00','1:30:00',
                                     '1:45:00','2:00:00','2:15:00','2:30:00','2:45:00','3:00:00','3:15:00',
                                     '3:30:00','3:45:00','4:00:00','4:15:00','4:30:00','4:45:00','5:00:00',
                                     '5:15:00','5:30:00','5:45:00','6:00:00','6:15:00','6:30:00','6:45:00',
                                     '7:00:00','7:15:00','7:30:00','7:45:00','8:00:00','8:15:00','8:30:00',
                                     '8:45:00','9:00:00','9:15:00','9:30:00','9:45:00','10:00:00','10:15:00',
                                     '10:30:00','10:45:00','11:00:00','11:15:00','11:30:00','11:45:00','12:00:00',
                                     '12:15:00','12:30:00','12:45:00','13:00:00','13:15:00','13:30:00','13:45:00',
                                     '14:00:00','14:15:00','14:30:00','14:45:00','15:00:00','15:15:00','15:30:00',
                                     '15:45:00','16:00:00','16:15:00','16:30:00','16:45:00','17:00:00','17:15:00',
                                     '17:30:00','17:45:00','18:00:00','18:15:00','18:30:00','18:45:00','19:00:00',
                                     '19:15:00','19:30:00','19:45:00','20:00:00','20:15:00','20:30:00','20:45:00',
                                     '21:00:00','21:15:00','21:30:00','21:45:00','22:00:00','22:15:00','22:30:00',
                                     '22:45:00','23:00:00','23:15:00','23:30:00','23:45:00'])

# %%
daily_view= daily_values_tt.plot.area(title='Power Production: TenneTTSO/2019-08-24')
daily_view.set_ylabel('TW/h Generated')
daily_view.set_xlabel('Time of Day')
# Out:
# Text(0.5, 0, 'Time of Day')

# %%
daily_values_tb = pd.DataFrame({'TransnetBW/2019-08-24':[22.43,22.25,22.03,23.34,24.81,22.9,22.77,19.49,22.58,23.15,22.01,
                                                21.81,21.44,20.24,19.19,19.96,19.21,18.89,15.21,17.01,16.06,16.36,
                                                15.49,14.23,13.52,11.64,10.65,9.56,6.19,4.38,3.47,2.32,1.64,1.36,
                                                0.86,0.86,0.57,0.66,0.69,0.56,0.54,0.86,1.01,0.97,0.49,0.69,1,0.82,
                                                0.91,1.44,1.21,1.83,1.61,1.8,1.36,1.43,1.5,0.9,1.14,1.62,2.03,1.85,
                                                2.12,2.36,1.27,2.03,2.32,2.27,1.63,1.45,1.95,3.45,3.89,2.8,3.37,3.72,
                                                3.99,4.51,4.38,3.9,2.92,2.61,3.32,3.24,2.79,2.45,1.67,1.35,1.34,0.97,
                                                1.41,1.5,1.3,1.23,1.15,1.01]},
                                index=['00:00:00', '0:15:00','0:30:00','0:45:00','1:00:00','1:15:00','1:30:00',
                                     '1:45:00','2:00:00','2:15:00','2:30:00','2:45:00','3:00:00','3:15:00',
                                     '3:30:00','3:45:00','4:00:00','4:15:00','4:30:00','4:45:00','5:00:00',
                                     '5:15:00','5:30:00','5:45:00','6:00:00','6:15:00','6:30:00','6:45:00',
                                     '7:00:00','7:15:00','7:30:00','7:45:00','8:00:00','8:15:00','8:30:00',
                                     '8:45:00','9:00:00','9:15:00','9:30:00','9:45:00','10:00:00','10:15:00',
                                     '10:30:00','10:45:00','11:00:00','11:15:00','11:30:00','11:45:00','12:00:00',
                                     '12:15:00','12:30:00','12:45:00','13:00:00','13:15:00','13:30:00','13:45:00',
                                     '14:00:00','14:15:00','14:30:00','14:45:00','15:00:00','15:15:00','15:30:00',
                                     '15:45:00','16:00:00','16:15:00','16:30:00','16:45:00','17:00:00','17:15:00',
                                     '17:30:00','17:45:00','18:00:00','18:15:00','18:30:00','18:45:00','19:00:00',
                                     '19:15:00','19:30:00','19:45:00','20:00:00','20:15:00','20:30:00','20:45:00',
                                     '21:00:00','21:15:00','21:30:00','21:45:00','22:00:00','22:15:00','22:30:00',
                                     '22:45:00','23:00:00','23:15:00','23:30:00','23:45:00'])

# %%
daily_view= daily_values_tb.plot.area(title='Power Production: TransnetBW/2019-08-24')
daily_view.set_ylabel('TW/h Generated')
daily_view.set_xlabel('Time of Day')
# Out:
# Text(0.5, 0, 'Time of Day')

# %% [markdown]
# Attempting the bonus

# %%
unified = pd.concat(daily_values_h,daily_values_a,
                    daily_values_tt,daily_values_tb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-6a6bdfaac542> in <module>
# ----> 1 unified = pd.concat(daily_values_h,daily_values_a,
#       2                     daily_values_tt,daily_values_tb)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     318     ):
#     319         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 320             raise TypeError(
# ...

# %%
unified
# Out:
#           2019/08/24  Amprion/2019-08-24  TenneTTSO/2019-08-24  \
# 00:00:00        37.0                 NaN                   NaN
# 0:15:00         38.0                 NaN                   NaN
# 0:30:00         35.0                 NaN                   NaN
# 0:45:00         35.0                 NaN                   NaN
# 1:00:00         31.0                 NaN                   NaN
# ...              ...                 ...                   ...
# 22:45:00         NaN                 NaN                   NaN
# 23:00:00         NaN                 NaN                   NaN
# 23:15:00         NaN                 NaN                   NaN
# 23:30:00         NaN                 NaN                   NaN
# 23:45:00         NaN                 NaN                   NaN
#
#           TransnetBW/2019-08-24
# 00:00:00                    NaN
# 0:15:00                     NaN
# 0:30:00                     NaN
# 0:45:00                     NaN
# 1:00:00                     NaN
# ...

# %% [markdown]
# Part 2

# %% [markdown]
# Line Chart

# %%
lines= daily_values_a.plot.line()

# %% [markdown]
# Box/Whisker

# %%
boxplot= hdf.boxplot(column=['00:00:00', '00:15:00','00:30:00'])

# %% [markdown]
# Histogram and Kernel Density

# %%
hist = noon.hist(bins=4)

# %%
kern = midnight.plot.kde()

# %% [markdown]
# Heatmap

# %%
heat= plt.imshow(noon, cmap ="RdYlBu")

# %% [markdown]
# Seaborn Pair Plot

# %%
sns.pairplot(noon)
